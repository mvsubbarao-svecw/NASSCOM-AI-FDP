# %% [markdown]
# <a href="https://colab.research.google.com/github/mvsubbarao-svecw/NASSCOM-AI-FDP/blob/main/D3_Pandas_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

print("--- Intermediate Pandas Exercise ---")
print("Complete each task by writing the requested Pandas code.")
print("------------------------------------")

# Task 1: Basic Pandas Functions and Converting Arrays to DataFrames
print("\n--- Task 1: Basic Pandas Functions and Converting Arrays to DataFrames ---")
# 1.1 Create a Pandas Series named 's1_1' from a list of numbers [10, 20, 30, 40, 50].
# 1.2 Create a 3x4 NumPy array named 'np_array1_2' with random integers between 1 and 100.
# 1.3 Convert 'np_array1_2' into a Pandas DataFrame named 'df1_3' with columns 'A', 'B', 'C', 'D'.
s1_1 = pd.Series([10, 20, 30, 40, 50])
np_array1_2 = np.random.randint(1, 101, size=(3, 4))
df1_3 = pd.DataFrame(np_array1_2, columns=['A', 'B', 'C', 'D'])
print('Data Frame:',df1_3)

# Task 2: Synthetic Data Generation for Practice
print("\n--- Task 2: Synthetic Data Generation for Practice ---")
# Create a DataFrame named 'df_sales' with 100 rows and the following columns:
# - 'Date': A range of dates from '2023-01-01' to '2023-04-09' (inclusive).
# - 'Region': Randomly chosen from ['East', 'West', 'North', 'South'].
# - 'Product': Randomly chosen from ['Laptop', 'Mouse', 'Keyboard', 'Monitor'].
# - 'Sales': Random integers between 100 and 1000.
# - 'Quantity': Random integers between 1 and 10.
# - Introduce 5 random NaN values in the 'Sales' column and 3 random NaN values in the 'Quantity' column.

df_sales =pd.DataFrame(101, index=pd.date_range('2023-01-01', '2023-04-10'), columns=['Region', 'Product', 'Sales', 'Quantity'])
df_sales=df_sales.reset_index()
df_sales.rename(columns={'index':'Date'}, inplace=True)
df_sales['Region'] = np.random.choice(['East', 'West', 'North', 'South'], size=100)
df_sales['Product'] = np.random.choice(['Laptop', 'Mouse', 'Keyboard', 'Monitor'], size=100)
df_sales['Sales'] = np.random.randint(101, 1000, size=100)
df_sales['Quantity'] = np.random.randint(1, 11, size=100)
print(df_sales)

# Introduce NaN values
df_sales.loc[np.random.choice(df_sales.index, 5), 'Sales'] = np.nan
df_sales.loc[np.random.choice(df_sales.index, 3), 'Quantity'] = np.nan
print(df_sales)


# Task 3: Indexing and Slicing in DataFrames
print("\n--- Task 3: Indexing and Slicing in DataFrames ---")
# Use 'df_sales' from Task 2.
# 3.1 Select only the 'Region' and 'Sales' columns. Store it in 'df3_1'.
# 3.2 Select rows where 'Product' is 'Laptop'. Store it in 'df3_2'.
# 3.3 Select rows where 'Region' is 'East' AND 'Sales' are greater than 500. Store it in 'df3_3'.
# 3.4 Select the 'Sales' value for the first entry where 'Product' is 'Monitor' (use .loc and .iloc). Store it in 'val3_4'.

df3_1 = df_sales[['Region', 'Sales']]
df3_2 = df_sales[df_sales['Product'] == 'Laptop']
df3_3 = df_sales[(df_sales['Region'] == 'East') & (df_sales['Sales'] > 500)]
val3_4 = df_sales.loc[df_sales['Product'] == 'Monitor', 'Sales'].iloc[0]
print('Data Frame only with Region and Sales:\n', df3_1)
print('Data Frame only with Product is Laptop:\n', df3_2)
print('Data Frame only with Region is 'East' and 'Sales' are greater than 500Rs\n', df3_3)
print('Data Frame 'val3_4)



# Task 4: Data Cleaning (Handling Missing Values)
print("\n--- Task 4: Data Cleaning (Handling Missing Values) ---")
# Use 'df_sales' from Task 2 (which should have NaNs).
# 4.1 Check how many missing values are in each column. Store the result in 'missing_counts4_1'.
# 4.2 Fill missing 'Sales' values with the mean of the 'Sales' column. Store the modified DataFrame in 'df4_2_filled'.
# 4.3 Drop rows that have any missing values in 'df_sales'. Store the result in 'df4_3_dropped'.

# Your code for Task 4 here:



# Task 5: Data Manipulation (Columns, Sorting, Grouping)
print("\n--- Task 5: Data Manipulation (Columns, Sorting, Grouping) ---")
# Use 'df_sales' (the original one with NaNs)
# 5.1 Create a new column 'Total_Revenue' which is 'Sales' * 'Quantity'.
#     (Be mindful of NaNs, the result should also be NaN where either Sales or Quantity is NaN).
# 5.2 Sort 'df_sales' by 'Date' in ascending order, then by 'Sales' in descending order. Store it in 'df5_2_sorted'.
# 5.3 Group 'df_sales' by 'Region' and calculate the sum of 'Sales' and 'Quantity' for each region.
#     Store the result in 'df5_3_grouped_region'.
# 5.4 Group 'df_sales' by 'Product' and find the average 'Sales' for each product.
#     Store the result in 'df5_4_grouped_product'.

# Your code for Task 5 here:
# Out:
#   File "/tmp/ipykernel_9646/205467810.py", line 57
#     print('Data Frame only with Region is 'East' and 'Sales' are greater than 500Rs\n', df3_3)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
import pandas as pd
import numpy as np

print("--- Intermediate Pandas Exercise ---")
print("Complete each task by writing the requested Pandas code.")
print("------------------------------------")

# Task 1: Basic Pandas Functions and Converting Arrays to DataFrames
print("\n--- Task 1: Basic Pandas Functions and Converting Arrays to DataFrames ---")
# 1.1 Create a Pandas Series named 's1_1' from a list of numbers [10, 20, 30, 40, 50].
# 1.2 Create a 3x4 NumPy array named 'np_array1_2' with random integers between 1 and 100.
# 1.3 Convert 'np_array1_2' into a Pandas DataFrame named 'df1_3' with columns 'A', 'B', 'C', 'D'.
s1_1 = pd.Series([10, 20, 30, 40, 50])
np_array1_2 = np.random.randint(1, 101, size=(3, 4))
df1_3 = pd.DataFrame(np_array1_2, columns=['A', 'B', 'C', 'D'])
print('Data Frame:',df1_3)

# Task 2: Synthetic Data Generation for Practice
print("\n--- Task 2: Synthetic Data Generation for Practice ---")
# Create a DataFrame named 'df_sales' with 100 rows and the following columns:
# - 'Date': A range of dates from '2023-01-01' to '2023-04-09' (inclusive).
# - 'Region': Randomly chosen from ['East', 'West', 'North', 'South'].
# - 'Product': Randomly chosen from ['Laptop', 'Mouse', 'Keyboard', 'Monitor'].
# - 'Sales': Random integers between 100 and 1000.
# - 'Quantity': Random integers between 1 and 10.
# - Introduce 5 random NaN values in the 'Sales' column and 3 random NaN values in the 'Quantity' column.

df_sales =pd.DataFrame(101, index=pd.date_range('2023-01-01', '2023-04-10'), columns=['Region', 'Product', 'Sales', 'Quantity'])
df_sales=df_sales.reset_index()
df_sales.rename(columns={'index':'Date'}, inplace=True)
df_sales['Region'] = np.random.choice(['East', 'West', 'North', 'South'], size=100)
df_sales['Product'] = np.random.choice(['Laptop', 'Mouse', 'Keyboard', 'Monitor'], size=100)
df_sales['Sales'] = np.random.randint(101, 1000, size=100)
df_sales['Quantity'] = np.random.randint(1, 11, size=100)
print(df_sales)

# Introduce NaN values
df_sales.loc[np.random.choice(df_sales.index, 5), 'Sales'] = np.nan
df_sales.loc[np.random.choice(df_sales.index, 3), 'Quantity'] = np.nan
print(df_sales)


# Task 3: Indexing and Slicing in DataFrames
print("\n--- Task 3: Indexing and Slicing in DataFrames ---")
# Use 'df_sales' from Task 2.
# 3.1 Select only the 'Region' and 'Sales' columns. Store it in 'df3_1'.
# 3.2 Select rows where 'Product' is 'Laptop'. Store it in 'df3_2'.
# 3.3 Select rows where 'Region' is 'East' AND 'Sales' are greater than 500. Store it in 'df3_3'.
# 3.4 Select the 'Sales' value for the first entry where 'Product' is 'Monitor' (use .loc and .iloc). Store it in 'val3_4'.

df3_1 = df_sales[['Region', 'Sales']]
df3_2 = df_sales[df_sales['Product'] == 'Laptop']
df3_3 = df_sales[(df_sales['Region'] == 'East') & (df_sales['Sales'] > 500)]
val3_4 = df_sales.loc[df_sales['Product'] == 'Monitor', 'Sales'].iloc[0]
print('Data Frame only with Region and Sales:\n', df3_1)
print('Data Frame only with Product is Laptop:\n', df3_2)
print('Data Frame only with Region is 'East' and 'Sales' are greater than 500Rs\n', df3_3)
print('Data Frame only with al3_4)



# Task 4: Data Cleaning (Handling Missing Values)
print("\n--- Task 4: Data Cleaning (Handling Missing Values) ---")
# Use 'df_sales' from Task 2 (which should have NaNs).
# 4.1 Check how many missing values are in each column. Store the result in 'missing_counts4_1'.
# 4.2 Fill missing 'Sales' values with the mean of the 'Sales' column. Store the modified DataFrame in 'df4_2_filled'.
# 4.3 Drop rows that have any missing values in 'df_sales'. Store the result in 'df4_3_dropped'.

# Your code for Task 4 here:



# Task 5: Data Manipulation (Columns, Sorting, Grouping)
print("\n--- Task 5: Data Manipulation (Columns, Sorting, Grouping) ---")
# Use 'df_sales' (the original one with NaNs)
# 5.1 Create a new column 'Total_Revenue' which is 'Sales' * 'Quantity'.
#     (Be mindful of NaNs, the result should also be NaN where either Sales or Quantity is NaN).
# 5.2 Sort 'df_sales' by 'Date' in ascending order, then by 'Sales' in descending order. Store it in 'df5_2_sorted'.
# 5.3 Group 'df_sales' by 'Region' and calculate the sum of 'Sales' and 'Quantity' for each region.
#     Store the result in 'df5_3_grouped_region'.
# 5.4 Group 'df_sales' by 'Product' and find the average 'Sales' for each product.
#     Store the result in 'df5_4_grouped_product'.

# Your code for Task 5 here:
# Out:
#   File "/tmp/ipykernel_9646/205467810.py", line 57
#     print('Data Frame only with Region is 'East' and 'Sales' are greater than 500Rs\n', df3_3)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
import pandas as pd
import numpy as np

print("--- Intermediate Pandas Exercise ---")
print("Complete each task by writing the requested Pandas code.")
print("------------------------------------")

# Task 1: Basic Pandas Functions and Converting Arrays to DataFrames
print("\n--- Task 1: Basic Pandas Functions and Converting Arrays to DataFrames ---")
# 1.1 Create a Pandas Series named 's1_1' from a list of numbers [10, 20, 30, 40, 50].
# 1.2 Create a 3x4 NumPy array named 'np_array1_2' with random integers between 1 and 100.
# 1.3 Convert 'np_array1_2' into a Pandas DataFrame named 'df1_3' with columns 'A', 'B', 'C', 'D'.
s1_1 = pd.Series([10, 20, 30, 40, 50])
np_array1_2 = np.random.randint(1, 101, size=(3, 4))
df1_3 = pd.DataFrame(np_array1_2, columns=['A', 'B', 'C', 'D'])
print('Data Frame:',df1_3)

# Task 2: Synthetic Data Generation for Practice
print("\n--- Task 2: Synthetic Data Generation for Practice ---")
# Create a DataFrame named 'df_sales' with 100 rows and the following columns:
# - 'Date': A range of dates from '2023-01-01' to '2023-04-09' (inclusive).
# - 'Region': Randomly chosen from ['East', 'West', 'North', 'South'].
# - 'Product': Randomly chosen from ['Laptop', 'Mouse', 'Keyboard', 'Monitor'].
# - 'Sales': Random integers between 100 and 1000.
# - 'Quantity': Random integers between 1 and 10.
# - Introduce 5 random NaN values in the 'Sales' column and 3 random NaN values in the 'Quantity' column.

df_sales =pd.DataFrame(101, index=pd.date_range('2023-01-01', '2023-04-10'), columns=['Region', 'Product', 'Sales', 'Quantity'])
df_sales=df_sales.reset_index()
df_sales.rename(columns={'index':'Date'}, inplace=True)
df_sales['Region'] = np.random.choice(['East', 'West', 'North', 'South'], size=100)
df_sales['Product'] = np.random.choice(['Laptop', 'Mouse', 'Keyboard', 'Monitor'], size=100)
df_sales['Sales'] = np.random.randint(101, 1000, size=100)
df_sales['Quantity'] = np.random.randint(1, 11, size=100)
print(df_sales)

# Introduce NaN values
df_sales.loc[np.random.choice(df_sales.index, 5), 'Sales'] = np.nan
df_sales.loc[np.random.choice(df_sales.index, 3), 'Quantity'] = np.nan
print(df_sales)


# Task 3: Indexing and Slicing in DataFrames
print("\n--- Task 3: Indexing and Slicing in DataFrames ---")
# Use 'df_sales' from Task 2.
# 3.1 Select only the 'Region' and 'Sales' columns. Store it in 'df3_1'.
# 3.2 Select rows where 'Product' is 'Laptop'. Store it in 'df3_2'.
# 3.3 Select rows where 'Region' is 'East' AND 'Sales' are greater than 500. Store it in 'df3_3'.
# 3.4 Select the 'Sales' value for the first entry where 'Product' is 'Monitor' (use .loc and .iloc). Store it in 'val3_4'.

df3_1 = df_sales[['Region', 'Sales']]
df3_2 = df_sales[df_sales['Product'] == 'Laptop']
df3_3 = df_sales[(df_sales['Region'] == 'East') & (df_sales['Sales'] > 500)]
val3_4 = df_sales.loc[df_sales['Product'] == 'Monitor', 'Sales'].iloc[0]
print('Data Frame only with Region and Sales:\n', df3_1)
print('Data Frame only with Product is Laptop:\n', df3_2)
print('Data Frame only with Region is East and Sales are greater than 500Rs\n', df3_3)
print('Data Frame only with Sales value for the first entry where Product is Monitor:\n', val3_4)



# Task 4: Data Cleaning (Handling Missing Values)
print("\n--- Task 4: Data Cleaning (Handling Missing Values) ---")
# Use 'df_sales' from Task 2 (which should have NaNs).
# 4.1 Check how many missing values are in each column. Store the result in 'missing_counts4_1'.
# 4.2 Fill missing 'Sales' values with the mean of the 'Sales' column. Store the modified DataFrame in 'df4_2_filled'.
# 4.3 Drop rows that have any missing values in 'df_sales'. Store the result in 'df4_3_dropped'.

missing_counts4_1 = df_sales.isnull().sum()
df4_2_filled = df_sales.copy()
df4_2_filled['Sales'].fillna(df4_2_filled['Sales'].mean(), inplace=True)
df4_3_dropped = df_sales.dropna()
print('Number of Missing Values: \n', missing_counts4_1)
print('DataFrame after filling with the mean of the Sales column:\n', df4_2_filled)
print('DataFrame after dropping the missing values', df4_3_dropped)



# Task 5: Data Manipulation (Columns, Sorting, Grouping)
print("\n--- Task 5: Data Manipulation (Columns, Sorting, Grouping) ---")
# Use 'df_sales' (the original one with NaNs)
# 5.1 Create a new column 'Total_Revenue' which is 'Sales' * 'Quantity'.
#     (Be mindful of NaNs, the result should also be NaN where either Sales or Quantity is NaN).
# 5.2 Sort 'df_sales' by 'Date' in ascending order, then by 'Sales' in descending order. Store it in 'df5_2_sorted'.
# 5.3 Group 'df_sales' by 'Region' and calculate the sum of 'Sales' and 'Quantity' for each region.
#     Store the result in 'df5_3_grouped_region'.
# 5.4 Group 'df_sales' by 'Product' and find the average 'Sales' for each product.
#     Store the result in 'df5_4_grouped_product'.

df5_1 = df_sales.copy()
df5_1['Total_Revenue'] = df5_1['Sales'] * df5_1['Quantity']
df5_2_sorted = df_sales.sort_values(by=['Date', 'Sales'], ascending=[True, False])
df5_3_grouped_region = df_sales.groupby('Region')[['Sales', 'Quantity']].sum()
df5_4_grouped_product = df_sales.groupby('Product')['Sales'].mean()
print('DataFrame with Total Revenue column:\n', df5_1)
print('DataFrame after sorting by Date in ascending order and Sales in descending order:\n', df5_2_sorted)
print('DataFrame after grouping by Region and calculating the sum of Sales and Quantity for each region:\n', df5_3_grouped_region)
print('DataFrame after grouping by Product and calculating the average Sales for each product:\n', df5_4_grouped_product)
# Out:
# --- Intermediate Pandas Exercise ---
# Complete each task by writing the requested Pandas code.
# ------------------------------------
#
# --- Task 1: Basic Pandas Functions and Converting Arrays to DataFrames ---
# Data Frame:     A   B   C   D
# 0  25  85  76  97
# 1  19  88  32  48
# 2  81  50  88  49
#
# --- Task 2: Synthetic Data Generation for Practice ---
#          Date Region   Product  Sales  Quantity
# 0  2023-01-01   East  Keyboard    757         2
# 1  2023-01-02   East    Laptop    834         9
# 2  2023-01-03   West  Keyboard    570         1
# 3  2023-01-04   East   Monitor    601        10
# 4  2023-01-05   East     Mouse    755         9
# ..        ...    ...       ...    ...       ...
# 95 2023-04-06  North  Keyboard    767         7
# 96 2023-04-07   West   Monitor    274         8
# 97 2023-04-08   West   Monitor    671         9
# 98 2023-04-09  South  Keyboard    482         1
# 99 2023-04-10   East   Monitor    834         8
#
# [100 rows x 5 columns]
#          Date Region   Product  Sales  Quantity
# 0  2023-01-01   East  Keyboard  757.0       2.0
# 1  2023-01-02   East    Laptop  834.0       NaN
# 2  2023-01-03   West  Keyboard  570.0       1.0
# 3  2023-01-04   East   Monitor  601.0      10.0
# 4  2023-01-05   East     Mouse  755.0       9.0
# ..        ...    ...       ...    ...       ...
# 95 2023-04-06  North  Keyboard    NaN       7.0
# 96 2023-04-07   West   Monitor  274.0       8.0
# 97 2023-04-08   West   Monitor  671.0       9.0
# 98 2023-04-09  South  Keyboard  482.0       1.0
# 99 2023-04-10   East   Monitor  834.0       8.0
#
# [100 rows x 5 columns]
#
# --- Task 3: Indexing and Slicing in DataFrames ---
# Data Frame only with Region and Sales:
#     Region  Sales
# 0    East  757.0
# 1    East  834.0
# 2    West  570.0
# 3    East  601.0
# 4    East  755.0
# ..    ...    ...
# 95  North    NaN
# 96   West  274.0
# 97   West  671.0
# 98  South  482.0
# 99   East  834.0
#
# [100 rows x 2 columns]
# Data Frame only with Product is Laptop:
#           Date Region Product  Sales  Quantity
# 1  2023-01-02   East  Laptop  834.0       NaN
# 5  2023-01-06  South  Laptop  246.0       2.0
# 6  2023-01-07   East  Laptop  183.0       9.0
# 21 2023-01-22  South  Laptop  495.0       2.0
# 22 2023-01-23  South  Laptop  135.0      10.0
# 23 2023-01-24   East  Laptop  830.0       7.0
# 26 2023-01-27   East  Laptop  585.0      10.0
# 30 2023-01-31  North  Laptop  467.0       7.0
# 34 2023-02-04  South  Laptop  556.0       9.0
# 36 2023-02-06  South  Laptop  805.0       7.0
# 44 2023-02-14   East  Laptop  996.0       4.0
# 45 2023-02-15   East  Laptop  873.0       5.0
# 48 2023-02-18  South  Laptop  180.0       6.0
# 50 2023-02-20  North  Laptop  980.0       7.0
# 52 2023-02-22  North  Laptop  434.0       9.0
# 53 2023-02-23   West  Laptop  621.0       9.0
# 60 2023-03-02  North  Laptop  907.0       5.0
# 62 2023-03-04   West  Laptop  802.0       3.0
# 67 2023-03-09  North  Laptop  928.0       9.0
# 68 2023-03-10   West  Laptop  978.0       1.0
# 72 2023-03-14   East  Laptop  993.0      10.0
# 74 2023-03-16   West  Laptop  226.0       2.0
# 76 2023-03-18  South  Laptop  189.0       6.0
# 82 2023-03-24  North  Laptop  760.0      10.0
# 85 2023-03-27  North  Laptop  425.0       2.0
# 86 2023-03-28   West  Laptop  584.0       4.0
# 92 2023-04-03   East  Laptop  481.0       4.0
# Data Frame only with Region is East and Sales are greater than 500Rs
#           Date Region   Product  Sales  Quantity
# 0  2023-01-01   East  Keyboard  757.0       2.0
# 1  2023-01-02   East    Laptop  834.0       NaN
# 3  2023-01-04   East   Monitor  601.0      10.0
# 4  2023-01-05   East     Mouse  755.0       9.0
# 10 2023-01-11   East     Mouse  521.0       5.0
# 19 2023-01-20   East  Keyboard  757.0       2.0
# 23 2023-01-24   East    Laptop  830.0       7.0
# 26 2023-01-27   East    Laptop  585.0      10.0
# 42 2023-02-12   East   Monitor  562.0       7.0
# 44 2023-02-14   East    Laptop  996.0       4.0
# 45 2023-02-15   East    Laptop  873.0       5.0
# 71 2023-03-13   East     Mouse  959.0       7.0
# 72 2023-03-14   East    Laptop  993.0      10.0
# 79 2023-03-21   East     Mouse  744.0       4.0
# 99 2023-04-10   East   Monitor  834.0       8.0
# Data Frame only with Sales value for the first entry where Product is Monitor:
#  601.0
#
# --- Task 4: Data Cleaning (Handling Missing Values) ---
# Number of Missing Values:
#  Date        0
# Region      0
# Product     0
# Sales       5
# Quantity    3
# dtype: int64
# DataFrame after filling with the mean of the Sales column:
#           Date Region   Product       Sales  Quantity
# 0  2023-01-01   East  Keyboard  757.000000       2.0
# 1  2023-01-02   East    Laptop  834.000000       NaN
# 2  2023-01-03   West  Keyboard  570.000000       1.0
# 3  2023-01-04   East   Monitor  601.000000      10.0
# 4  2023-01-05   East     Mouse  755.000000       9.0
# ..        ...    ...       ...         ...       ...
# 95 2023-04-06  North  Keyboard  587.031579       7.0
# 96 2023-04-07   West   Monitor  274.000000       8.0
# 97 2023-04-08   West   Monitor  671.000000       9.0
# 98 2023-04-09  South  Keyboard  482.000000       1.0
# 99 2023-04-10   East   Monitor  834.000000       8.0
#
# [100 rows x 5 columns]
# DataFrame after dropping the missing values          Date Region   Product  Sales  Quantity
# 0  2023-01-01   East  Keyboard  757.0       2.0
# 2  2023-01-03   West  Keyboard  570.0       1.0
# 3  2023-01-04   East   Monitor  601.0      10.0
# 4  2023-01-05   East     Mouse  755.0       9.0
# 5  2023-01-06  South    Laptop  246.0       2.0
# ..        ...    ...       ...    ...       ...
# 94 2023-04-05  North     Mouse  207.0       2.0
# 96 2023-04-07   West   Monitor  274.0       8.0
# 97 2023-04-08   West   Monitor  671.0       9.0
# 98 2023-04-09  South  Keyboard  482.0       1.0
# 99 2023-04-10   East   Monitor  834.0       8.0
#
# [93 rows x 5 columns]
#
# --- Task 5: Data Manipulation (Columns, Sorting, Grouping) ---
# DataFrame with Total Revenue column:
#           Date Region   Product  Sales  Quantity  Total_Revenue
# 0  2023-01-01   East  Keyboard  757.0       2.0         1514.0
# 1  2023-01-02   East    Laptop  834.0       NaN            NaN
# 2  2023-01-03   West  Keyboard  570.0       1.0          570.0
# 3  2023-01-04   East   Monitor  601.0      10.0         6010.0
# 4  2023-01-05   East     Mouse  755.0       9.0         6795.0
# ..        ...    ...       ...    ...       ...            ...
# 95 2023-04-06  North  Keyboard    NaN       7.0            NaN
# 96 2023-04-07   West   Monitor  274.0       8.0         2192.0
# 97 2023-04-08   West   Monitor  671.0       9.0         6039.0
# 98 2023-04-09  South  Keyboard  482.0       1.0          482.0
# 99 2023-04-10   East   Monitor  834.0       8.0         6672.0
#
# [100 rows x 6 columns]
# DataFrame after sorting by Date in ascending order and Sales in descending order:
#           Date Region   Product  Sales  Quantity
# 0  2023-01-01   East  Keyboard  757.0       2.0
# 1  2023-01-02   East    Laptop  834.0       NaN
# 2  2023-01-03   West  Keyboard  570.0       1.0
# 3  2023-01-04   East   Monitor  601.0      10.0
# 4  2023-01-05   East     Mouse  755.0       9.0
# ..        ...    ...       ...    ...       ...
# 95 2023-04-06  North  Keyboard    NaN       7.0
# 96 2023-04-07   West   Monitor  274.0       8.0
# 97 2023-04-08   West   Monitor  671.0       9.0
# 98 2023-04-09  South  Keyboard  482.0       1.0
# 99 2023-04-10   East   Monitor  834.0       8.0
#
# [100 rows x 5 columns]
# DataFrame after grouping by Region and calculating the sum of Sales and Quantity for each region:
#            Sales  Quantity
# Region
# East    14529.0     135.0
# North   15467.0     138.0
# South   13091.0     118.0
# West    12681.0     109.0
# DataFrame after grouping by Product and calculating the average Sales for each product:
#  Product
# Keyboard    577.000000
# Laptop      610.851852
# Monitor     601.115385
# Mouse       550.272727
# Name: Sales, dtype: float64
# /tmp/ipykernel_9646/140589924.py:71: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df4_2_filled['Sales'].fillna(df4_2_filled['Sales'].mean(), inplace=True)
